# %%
#Holiday Information

# %% [markdown]
# This purpose of the notebook is to collect user input of intended traveler, and then display information about the holiday.

# %%
from PIL import Image

# %%
def your_name():
    user_input = input("Enter your name please. : ")
    bullet1= '° Visiting the water park'
    bullet2= '° Sky diving'
    bullet3= '° Musuems'
    print (user_input)
    print (bullet1)
    print (bullet2)
    print (bullet3)

# %%
your_name()
# Out:
# Enter your name please. : Masquerade
# Masquerade
# ° Visiting the water park
# ° Sky diving
# ° Musuems

# %% [markdown]
# ![6DB6CB7F-5916-46CB-87B1-BFDB3F432BA3_1_105_c.jpeg](attachment:6DB6CB7F-5916-46CB-87B1-BFDB3F432BA3_1_105_c.jpeg)

# %% [markdown]
# ![Holidayloc.jpeg](attachment:Holidayloc.jpeg)
